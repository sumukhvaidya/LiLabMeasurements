# %%
import sys

# Add a directory to the Python path
directory_path = "C:\\Users\\Li_Lab_B12\\Desktop\\DataSumukh\\250731_PythonCode\\Main\\"
sys.path.append(directory_path)

import importlib
import confocal_Microscope
# Reload the module
importlib.reload(confocal_Microscope)

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Taking a Confocal Scan
# Perform a simple 2D Confocal counts scan.

# %%
# Testing a confocal scan
parameters = {
'samples_per_axis' : 21,
'scale' : 4,
'count_time (ms)': 10, 
'LED': False,
'reset': True
}

x,y = parameters['samples_per_axis']//2, parameters['samples_per_axis']//2

# confocal.close()


confocal = confocal_Microscope.confocal_Microscope()
conf_data = confocal.perform_2d_scan(parameters)
confocal.close()
# Out:
# 100%|██████████| 21/21 [00:11<00:00,  1.81it/s]

# %% [markdown]
# ### Testing a simple_continuous_counter
# Run the counter until the Q key is pressed

# %%
# Testing a confocal scan
parameters = {
'samples_per_axis' : 21,
'scale' : 4,
'count_time (ms)': 100, 
'LED': False,
'reset': True,
'window_size':30
}

x,y = parameters['samples_per_axis']//2, parameters['samples_per_axis']//2

# confocal.close()

confocal = confocal_Microscope.confocal_Microscope()
conf_data = confocal.simple_continuous_counter( x, y, parameters)
confocal.close()
# Out:
# Terminating loop...
